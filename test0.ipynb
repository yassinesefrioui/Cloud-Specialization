# %% [markdown]
# <a href="https://colab.research.google.com/github/yassinesefrioui/Cloud-Specialization/blob/main/test0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  print('hello')

# %%
hello()
# Out:
# hello

# %%
## test

# %%
##test
